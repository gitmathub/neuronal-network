# %%
# https://towardsdatascience.com/how-to-build-a-simple-neural-network-from-scratch-with-python-9f011896d2f3

import numpy as np

def sigmoid(z):
    return 1/(1 + np.exp(-z))

def initialize_parameters(neurons_count_input_layer, neurons_count_hidden_layer, neurons_count_output_layer):
    weight1 = np.random.randn(neurons_count_hidden_layer, neurons_count_input_layer)
    bias1 = np.zeros((neurons_count_hidden_layer, 1))
    weight2 = np.random.randn(neurons_count_output_layer, neurons_count_hidden_layer)
    bias2 = np.zeros((neurons_count_output_layer, 1))

    parameters = {
        "weight1": weight1,
        "bias1" : bias1,
        "weight2": weight2,
        "bias2" : bias2
    }
    return parameters

def forward_prop(X, parameters):
    weight1 = parameters["weight1"]
    bias1 = parameters["bias1"]
    weight2 = parameters["weight2"]
    bias2 = parameters["bias2"]

    Z1 = np.dot(weight1, X) + bias1
    A1 = np.tanh(Z1)
#    A1 = sigmoid(Z1)
    Z2 = np.dot(weight2, A1) + bias2
    A2 = sigmoid(Z2)
#    A2 = np.tanh(Z2)

    cache = {
        "A1": A1,
        "A2": A2
    }
    return A2, cache

def calculate_cost(A2, Y):
    cost = -np.sum(np.multiply(Y, np.log(A2)) +  np.multiply(1-Y, np.log(1-A2)))/m
    cost = np.squeeze(cost)

    return cost

def backward_prop(X, Y, cache, parameters):
    A1 = cache["A1"]
    A2 = cache["A2"]

    weight2 = parameters["weight2"]

    dZ2 = A2 - Y
    dweight2 = np.dot(dZ2, A1.T)/m
    dbias2 = np.sum(dZ2, axis=1, keepdims=True)/m
    dZ1 = np.multiply(np.dot(weight2.T, dZ2), 1-np.power(A1, 2))
    dweight1 = np.dot(dZ1, X.T)/m
    dbias1 = np.sum(dZ1, axis=1, keepdims=True)/m

    grads = {
        "dweight1": dweight1,
        "dbias1": dbias1,
        "dweight2": dweight2,
        "dbias2": dbias2
    }

    return grads

def update_parameters(parameters, grads, learning_rate):
    weight1 = parameters["weight1"]
    bias1 = parameters["bias1"]
    weight2 = parameters["weight2"]
    bias2 = parameters["bias2"]

    dweight1 = grads["dweight1"]
    dbias1 = grads["dbias1"]
    dweight2 = grads["dweight2"]
    dbias2 = grads["dbias2"]

    weight1 = weight1 - learning_rate*dweight1
    bias1 = bias1 - learning_rate*dbias1
    weight2 = weight2 - learning_rate*dweight2
    bias2 = bias2 - learning_rate*dbias2
    
    new_parameters = {
        "weight1": weight1,
        "weight2": weight2,
        "bias1" : bias1,
        "bias2" : bias2
    }

    return new_parameters


def model(X, Y, neurons_count_input_layer, neurons_count_hidden_layer, neurons_count_output_layer, num_of_iters, learning_rate):
    parameters = initialize_parameters(neurons_count_input_layer, neurons_count_hidden_layer, neurons_count_output_layer)

    for i in range(0, num_of_iters+1):
        a2, cache = forward_prop(X, parameters)

        cost = calculate_cost(a2, Y)

        grads = backward_prop(X, Y, cache, parameters)

        parameters = update_parameters(parameters, grads, learning_rate)

        if(i%50 == 0):
            print('Cost after iteration# {:d}: {:f}'.format(i, cost))
#            print('cache', cache)
            print('grads', grads)
#            print('parameters', parameters)

    return parameters

def predict(X, parameters):
    a2, cache = forward_prop(X, parameters)
    yhat = a2
    yhat = np.squeeze(yhat)
    if(yhat >= 0.5):
        y_predict = 1
    else:
        y_predict = 0

    return y_predict
    


np.random.seed(2)

# The 4 training examples by columns
X = np.array([[0, 0, 1, 1], [0, 1, 0, 1]])

# The outputs of the XOR for every example in X
Y = np.array([[0, 1, 1, 0]])

# No. of training examples
m = X.shape[1]

# Set the hyperparameters
neurons_count_input_layer = 2     #No. of neurons in first layer
neurons_count_hidden_layer = 2     #No. of neurons in hidden layer
neurons_count_output_layer = 1     #No. of neurons in output layer
num_of_iters = 10000
learning_rate = 0.3

trained_parameters = model(X, Y, neurons_count_input_layer, neurons_count_hidden_layer, neurons_count_output_layer, num_of_iters, learning_rate)

# Test 2X1 vector to calculate the XOR of its elements. 
# Try (0, 0), (0, 1), (1, 0), (1, 1)

X_test = np.array([[1], [1]])
y_predict = predict(X_test, trained_parameters)
print('Neural Network prediction for example (1,1) is {:d}'.format(y_predict))

X_test = np.array([[0], [1]])
y_predict = predict(X_test, trained_parameters)
print('Neural Network prediction for example (0,1) is {:d}'.format(y_predict))

X_test = np.array([[0], [0]])
y_predict = predict(X_test, trained_parameters)
print('Neural Network prediction for example (0,0) is {:d}'.format(y_predict))

X_test = np.array([[1], [0]])
y_predict = predict(X_test, trained_parameters)
print('Neural Network prediction for example (1,0) is {:d}'.format(y_predict))
# Out:
# Cost after iteration# 0: 0.856267
# grads {'dweight1': array([[-0.20850296,  0.02049162],
#        [-0.12492949, -0.10745412]]), 'dbias1': array([[-0.13603693],
#        [-0.21063238]]), 'dweight2': array([[-0.05726626, -0.19815821]]), 'dbias2': array([[0.1054896]])}
# Cost after iteration# 50: 0.503667
# grads {'dweight1': array([[-0.02761564,  0.01814891],
#        [ 0.02764883, -0.02626384]]), 'dbias1': array([[-0.00162985],
#        [-0.02037731]]), 'dweight2': array([[0.02356708, 0.06216107]]), 'dbias2': array([[-0.03324471]])}
# Cost after iteration# 100: 0.347426
# grads {'dweight1': array([[-0.05169183,  0.03862595],
#        [ 0.03076282, -0.01913592]]), 'dbias1': array([[-0.03096171],
#        [-0.0077317 ]]), 'dweight2': array([[0.03170799, 0.04121168]]), 'dbias2': array([[-0.06792659]])}
# Cost after iteration# 150: 0.171442
# grads {'dweight1': array([[-0.03675009,  0.03477031],
#        [ 0.01519262, -0.0112744 ]]), 'dbias1': array([[-0.02267367],
#        [-0.00605038]]), 'dweight2': array([[0.02952891, 0.02893604]]), 'dbias2': array([[-0.04679906]])}
# Cost after iteration# 200: 0.101195
# grads {'dweight1': array([[-0.02016748,  0.01980425],
#        [ 0.00892684, -0.00748259]]), 'dbias1': array([[-0.01179359],
#        [-0.00409458]]), 'dweight2': array([[0.02230342, 0.02193525]]), 'dbias2': array([[-0.02834173]])}
# Cost after iteration# 250: 0.070423
# grads {'dweight1': array([[-0.01299347,  0.01289776],
#        [ 0.00622853, -0.00549926]]), 'dbias1': array([[-0.00729071],
#        [-0.00291676]]), 'dweight2': array([[0.01704552, 0.01714027]]), 'dbias2': array([[-0.01995173]])}
# Cost after iteration# 300: 0.053631
# grads {'dweight1': array([[-0.00931752,  0.00928653],
#        [ 0.00473726, -0.00430739]]), 'dbias1': array([[-0.00508047],
#        [-0.00222982]]), 'dweight2': array([[0.01363895, 0.01388039]]), 'dbias2': array([[-0.01535296]])}
# Cost after iteration# 350: 0.043155
# grads {'dweight1': array([[-0.00715027,  0.00713815],
#        [ 0.00379797, -0.00352023]]), 'dbias1': array([[-0.00382105],
#        [-0.00179184]]), 'dweight2': array([[0.01132287, 0.01159228]]), 'dbias2': array([[-0.01246756]])}
# Cost after iteration# 400: 0.036031
# grads {'dweight1': array([[-0.00574403,  0.00573771],
#        [ 0.00315591, -0.00296507]]), 'dbias1': array([[-0.00302499],
#        [-0.00149129]]), 'dweight2': array([[0.0096623 , 0.00992092]]), 'dbias2': array([[-0.01049135]])}
# Cost after iteration# 450: 0.030885
# grads {'dweight1': array([[-0.0047677 ,  0.00476299],
#        [ 0.0026913 , -0.00255425]]), 'dbias1': array([[-0.0024834],
#        [-0.0012734]]), 'dweight2': array([[0.00841878, 0.00865546]]), 'dbias2': array([[-0.00905386]])}
# Cost after iteration# 500: 0.027002
# grads {'dweight1': array([[-0.00405519,  0.00405066],
#        [ 0.00234063, -0.00223892]]), 'dbias1': array([[-0.00209442],
#        [-0.00110875]]), 'dweight2': array([[0.00745485, 0.00766797]]), 'dbias2': array([[-0.00796155]])}
# Cost after iteration# 550: 0.023971
# grads {'dweight1': array([[-0.00351497,  0.00351018],
#        [ 0.00206723, -0.0019898 ]]), 'dbias1': array([[-0.00180324],
#        [-0.00098024]]), 'dweight2': array([[0.00668673, 0.00687788]]), 'dbias2': array([[-0.00710359]])}
# Cost after iteration# 600: 0.021543
# grads {'dweight1': array([[-0.00309288,  0.00308773],
#        [ 0.00184848, -0.00178836]]), 'dbias1': array([[-0.0015781 ],
#        [-0.00087733]]), 'dweight2': array([[0.00606077, 0.0062324 ]]), 'dbias2': array([[-0.00641196]])}
# Cost after iteration# 650: 0.019554
# grads {'dweight1': array([[-0.00275498,  0.00274951],
#        [ 0.00166975, -0.00162234]]), 'dbias1': array([[-0.00139942],
#        [-0.00079319]]), 'dweight2': array([[0.00554112, 0.00569574]]), 'dbias2': array([[-0.00584265]])}
# Cost after iteration# 700: 0.017896
# grads {'dweight1': array([[-0.00247902,  0.00247328],
#        [ 0.00152116, -0.0014833 ]]), 'dbias1': array([[-0.00125454],
#        [-0.00072317]]), 'dweight2': array([[0.00510299, 0.00524288]]), 'dbias2': array([[-0.00536588]])}
# Cost after iteration# 750: 0.016494
# grads {'dweight1': array([[-0.00224983,  0.00224389],
#        [ 0.00139578, -0.00136526]]), 'dbias1': array([[-0.00113495],
#        [-0.00066405]]), 'dweight2': array([[0.0047287 , 0.00485583]]), 'dbias2': array([[-0.00496082]])}
# Cost after iteration# 800: 0.015293
# grads {'dweight1': array([[-0.00205675,  0.00205068],
#        [ 0.00128867, -0.00126388]]), 'dbias1': array([[-0.00103473],
#        [-0.00061351]]), 'dweight2': array([[0.0044053 , 0.00452136]]), 'dbias2': array([[-0.00461246]])}
# Cost after iteration# 850: 0.014253
# grads {'dweight1': array([[-0.0018921 ,  0.00188595],
#        [ 0.00119617, -0.00117591]]), 'dbias1': array([[-0.00094967],
#        [-0.00056983]]), 'dweight2': array([[0.00412312, 0.00422954]]), 'dbias2': array([[-0.00430967]])}
# Cost after iteration# 900: 0.013344
# grads {'dweight1': array([[-0.00175019,  0.001744  ],
#        [ 0.00111552, -0.00109891]]), 'dbias1': array([[-0.00087664],
#        [-0.00053173]]), 'dweight2': array([[0.00387478, 0.00397276]]), 'dbias2': array([[-0.00404409]])}
# Cost after iteration# 950: 0.012543
# grads {'dweight1': array([[-0.00162673,  0.00162054],
#        [ 0.00104462, -0.00103097]]), 'dbias1': array([[-0.00081333],
#        [-0.00049821]]), 'dweight2': array([[0.00365456, 0.00374512]]), 'dbias2': array([[-0.00380926]])}
# Cost after iteration# 1000: 0.011831
# grads {'dweight1': array([[-0.00151844,  0.00151228],
#        [ 0.00098183, -0.0009706 ]]), 'dbias1': array([[-0.00075797],
#        [-0.00046851]]), 'dweight2': array([[0.00345796, 0.00354195]]), 'dbias2': array([[-0.00360014]])}
# Cost after iteration# 1050: 0.011195
# grads {'dweight1': array([[-0.00142276,  0.00141664],
#        [ 0.00092585, -0.00091664]]), 'dbias1': array([[-0.0007092 ],
#        [-0.00044202]]), 'dweight2': array([[0.00328138, 0.00335953]]), 'dbias2': array([[-0.00341274]])}
# Cost after iteration# 1100: 0.010623
# grads {'dweight1': array([[-0.00133766,  0.0013316 ],
#        [ 0.00087566, -0.00086812]]), 'dbias1': array([[-0.00066592],
#        [-0.00041825]]), 'dweight2': array([[0.00312191, 0.00319487]]), 'dbias2': array([[-0.00324384]])}
# Cost after iteration# 1150: 0.010106
# grads {'dweight1': array([[-0.00126152,  0.00125553],
#        [ 0.0008304 , -0.00082428]]), 'dbias1': array([[-0.00062729],
#        [-0.00039681]]), 'dweight2': array([[0.0029772, 0.0030455]]), 'dbias2': array([[-0.00309083]])}
# Cost after iteration# 1200: 0.009637
# grads {'dweight1': array([[-0.00119304,  0.00118713],
#        [ 0.00078941, -0.00078447]]), 'dbias1': array([[-0.00059262],
#        [-0.00037738]]), 'dweight2': array([[0.00284528, 0.00290939]]), 'dbias2': array([[-0.00295159]])}
# Cost after iteration# 1250: 0.009209
# grads {'dweight1': array([[-0.00113114,  0.00112532],
#        [ 0.00075211, -0.00074818]]), 'dbias1': array([[-0.00056134],
#        [-0.00035969]]), 'dweight2': array([[0.00272455, 0.00278487]]), 'dbias2': array([[-0.00282432]])}
# Cost after iteration# 1300: 0.008817
# grads {'dweight1': array([[-0.00107495,  0.00106921],
#        [ 0.00071803, -0.00071497]]), 'dbias1': array([[-0.00053299],
#        [-0.00034352]]), 'dweight2': array([[0.00261363, 0.00267051]]), 'dbias2': array([[-0.00270756]])}
# Cost after iteration# 1350: 0.008457
# grads {'dweight1': array([[-0.00102372,  0.00101808],
#        [ 0.00068679, -0.00068446]]), 'dbias1': array([[-0.00050718],
#        [-0.00032869]]), 'dweight2': array([[0.00251137, 0.00256514]]), 'dbias2': array([[-0.00260005]])}
# Cost after iteration# 1400: 0.008124
# grads {'dweight1': array([[-0.00097685,  0.00097131],
#        [ 0.00065804, -0.00065635]]), 'dbias1': array([[-0.0004836 ],
#        [-0.00031504]]), 'dweight2': array([[0.00241681, 0.00246773]]), 'dbias2': array([[-0.00250074]])}
# Cost after iteration# 1450: 0.007817
# grads {'dweight1': array([[-0.00093382,  0.00092837],
#        [ 0.0006315 , -0.00063036]]), 'dbias1': array([[-0.00046199],
#        [-0.00030244]]), 'dweight2': array([[0.00232911, 0.00237742]]), 'dbias2': array([[-0.00240873]])}
# Cost after iteration# 1500: 0.007532
# grads {'dweight1': array([[-0.00089418,  0.00088883],
#        [ 0.00060693, -0.00060627]]), 'dbias1': array([[-0.0004421 ],
#        [-0.00029077]]), 'dweight2': array([[0.00224755, 0.00229347]]), 'dbias2': array([[-0.00232323]])}
# Cost after iteration# 1550: 0.007267
# grads {'dweight1': array([[-0.00085756,  0.0008523 ],
#        [ 0.00058413, -0.00058389]]), 'dbias1': array([[-0.00042375],
#        [-0.00027993]]), 'dweight2': array([[0.0021715 , 0.00221522]]), 'dbias2': array([[-0.00224359]])}
# Cost after iteration# 1600: 0.007019
# grads {'dweight1': array([[-0.00082364,  0.00081847],
#        [ 0.00056291, -0.00056303]]), 'dbias1': array([[-0.00040676],
#        [-0.00026984]]), 'dweight2': array([[0.00210043, 0.00214211]]), 'dbias2': array([[-0.00216923]])}
# Cost after iteration# 1650: 0.006788
# grads {'dweight1': array([[-0.00079213,  0.00078706],
#        [ 0.00054311, -0.00054355]]), 'dbias1': array([[-0.000391  ],
#        [-0.00026042]]), 'dweight2': array([[0.00203386, 0.00207367]]), 'dbias2': array([[-0.00209963]])}
# Cost after iteration# 1700: 0.006572
# grads {'dweight1': array([[-0.0007628 ,  0.00075781],
#        [ 0.00052461, -0.00052532]]), 'dbias1': array([[-0.00037634],
#        [-0.00025162]]), 'dweight2': array([[0.00197138, 0.00200944]]), 'dbias2': array([[-0.00203435]])}
# Cost after iteration# 1750: 0.006368
# grads {'dweight1': array([[-0.00073542,  0.00073053],
#        [ 0.00050727, -0.00050823]]), 'dbias1': array([[-0.00036268],
#        [-0.00024336]]), 'dweight2': array([[0.00191262, 0.00194907]]), 'dbias2': array([[-0.001973]])}
# Cost after iteration# 1800: 0.006177
# grads {'dweight1': array([[-0.00070983,  0.00070502],
#        [ 0.00049099, -0.00049217]]), 'dbias1': array([[-0.00034991],
#        [-0.00023562]]), 'dweight2': array([[0.00185727, 0.00189221]]), 'dbias2': array([[-0.00191524]])}
# Cost after iteration# 1850: 0.005997
# grads {'dweight1': array([[-0.00068584,  0.00068112],
#        [ 0.00047569, -0.00047705]]), 'dbias1': array([[-0.00033795],
#        [-0.00022833]]), 'dweight2': array([[0.00180503, 0.00183857]]), 'dbias2': array([[-0.00186077]])}
# Cost after iteration# 1900: 0.005827
# grads {'dweight1': array([[-0.00066333,  0.00065868],
#        [ 0.00046127, -0.0004628 ]]), 'dbias1': array([[-0.00032674],
#        [-0.00022146]]), 'dweight2': array([[0.00175565, 0.00178787]]), 'dbias2': array([[-0.0018093]])}
# Cost after iteration# 1950: 0.005667
# grads {'dweight1': array([[-0.00064215,  0.00063759],
#        [ 0.00044767, -0.00044934]]), 'dbias1': array([[-0.00031619],
#        [-0.00021498]]), 'dweight2': array([[0.0017089 , 0.00173989]]), 'dbias2': array([[-0.0017606]])}
# Cost after iteration# 2000: 0.005515
# grads {'dweight1': array([[-0.0006222 ,  0.00061772],
#        [ 0.00043481, -0.00043661]]), 'dbias1': array([[-0.00030627],
#        [-0.00020885]]), 'dweight2': array([[0.00166458, 0.00169442]]), 'dbias2': array([[-0.00171446]])}
# Cost after iteration# 2050: 0.005370
# grads {'dweight1': array([[-0.00060338,  0.00059898],
#        [ 0.00042264, -0.00042455]]), 'dbias1': array([[-0.00029691],
#        [-0.00020305]]), 'dweight2': array([[0.0016225 , 0.00165125]]), 'dbias2': array([[-0.00167066]])}
# Cost after iteration# 2100: 0.005233
# grads {'dweight1': array([[-0.0005856 ,  0.00058127],
#        [ 0.00041111, -0.00041312]]), 'dbias1': array([[-0.00028808],
#        [-0.00019755]]), 'dweight2': array([[0.00158249, 0.00161023]]), 'dbias2': array([[-0.00162905]])}
# Cost after iteration# 2150: 0.005103
# grads {'dweight1': array([[-0.00056877,  0.00056451],
#        [ 0.00040017, -0.00040226]]), 'dbias1': array([[-0.00027972],
#        [-0.00019233]]), 'dweight2': array([[0.00154441, 0.00157119]]), 'dbias2': array([[-0.00158946]])}
# Cost after iteration# 2200: 0.004979
# grads {'dweight1': array([[-0.00055282,  0.00054864],
#        [ 0.00038976, -0.00039193]]), 'dbias1': array([[-0.0002718 ],
#        [-0.00018736]]), 'dweight2': array([[0.00150812, 0.001534  ]]), 'dbias2': array([[-0.00155175]])}
# Cost after iteration# 2250: 0.004861
# grads {'dweight1': array([[-0.00053769,  0.00053357],
#        [ 0.00037987, -0.0003821 ]]), 'dbias1': array([[-0.0002643 ],
#        [-0.00018264]]), 'dweight2': array([[0.0014735 , 0.00149853]]), 'dbias2': array([[-0.00151578]])}
# Cost after iteration# 2300: 0.004749
# grads {'dweight1': array([[-0.00052331,  0.00051927],
#        [ 0.00037044, -0.00037274]]), 'dbias1': array([[-0.00025717],
#        [-0.00017814]]), 'dweight2': array([[0.00144044, 0.00146465]]), 'dbias2': array([[-0.00148145]])}
# Cost after iteration# 2350: 0.004641
# grads {'dweight1': array([[-0.00050964,  0.00050566],
#        [ 0.00036146, -0.0003638 ]]), 'dbias1': array([[-0.00025039],
#        [-0.00017385]]), 'dweight2': array([[0.00140882, 0.00143227]]), 'dbias2': array([[-0.00144863]])}
# Cost after iteration# 2400: 0.004538
# grads {'dweight1': array([[-0.00049662,  0.0004927 ],
#        [ 0.00035288, -0.00035526]]), 'dbias1': array([[-0.00024394],
#        [-0.00016975]]), 'dweight2': array([[0.00137857, 0.0014013 ]]), 'dbias2': array([[-0.00141723]])}
# Cost after iteration# 2450: 0.004440
# grads {'dweight1': array([[-0.00048421,  0.00048035],
#        [ 0.00034468, -0.0003471 ]]), 'dbias1': array([[-0.00023779],
#        [-0.00016584]]), 'dweight2': array([[0.00134959, 0.00137163]]), 'dbias2': array([[-0.00138717]])}
# Cost after iteration# 2500: 0.004346
# grads {'dweight1': array([[-0.00047237,  0.00046857],
#        [ 0.00033684, -0.0003393 ]]), 'dbias1': array([[-0.00023193],
#        [-0.00016209]]), 'dweight2': array([[0.0013218 , 0.00134319]]), 'dbias2': array([[-0.00135835]])}
# Cost after iteration# 2550: 0.004256
# grads {'dweight1': array([[-0.00046106,  0.00045732],
#        [ 0.00032933, -0.00033182]]), 'dbias1': array([[-0.00022633],
#        [-0.00015851]]), 'dweight2': array([[0.00129514, 0.0013159 ]]), 'dbias2': array([[-0.00133071]])}
# Cost after iteration# 2600: 0.004169
# grads {'dweight1': array([[-0.00045024,  0.00044656],
#        [ 0.00032214, -0.00032465]]), 'dbias1': array([[-0.00022098],
#        [-0.00015507]]), 'dweight2': array([[0.00126953, 0.0012897 ]]), 'dbias2': array([[-0.00130417]])}
# Cost after iteration# 2650: 0.004086
# grads {'dweight1': array([[-0.00043989,  0.00043627],
#        [ 0.00031524, -0.00031777]]), 'dbias1': array([[-0.00021586],
#        [-0.00015177]]), 'dweight2': array([[0.00124491, 0.00126452]]), 'dbias2': array([[-0.00127867]])}
# Cost after iteration# 2700: 0.004006
# grads {'dweight1': array([[-0.00042998,  0.00042641],
#        [ 0.00030862, -0.00031117]]), 'dbias1': array([[-0.00021096],
#        [-0.00014861]]), 'dweight2': array([[0.00122124, 0.00124031]]), 'dbias2': array([[-0.00125414]])}
# Cost after iteration# 2750: 0.003929
# grads {'dweight1': array([[-0.00042048,  0.00041696],
#        [ 0.00030226, -0.00030482]]), 'dbias1': array([[-0.00020627],
#        [-0.00014557]]), 'dweight2': array([[0.00119844, 0.001217  ]]), 'dbias2': array([[-0.00123054]])}
# Cost after iteration# 2800: 0.003855
# grads {'dweight1': array([[-0.00041136,  0.0004079 ],
#        [ 0.00029615, -0.00029872]]), 'dbias1': array([[-0.00020176],
#        [-0.00014264]]), 'dweight2': array([[0.00117649, 0.00119456]]), 'dbias2': array([[-0.00120781]])}
# Cost after iteration# 2850: 0.003783
# grads {'dweight1': array([[-0.00040261,  0.00039919],
#        [ 0.00029027, -0.00029285]]), 'dbias1': array([[-0.00019744],
#        [-0.00013983]]), 'dweight2': array([[0.00115532, 0.00117292]]), 'dbias2': array([[-0.00118591]])}
# Cost after iteration# 2900: 0.003715
# grads {'dweight1': array([[-0.0003942 ,  0.00039083],
#        [ 0.00028461, -0.00028719]]), 'dbias1': array([[-0.00019329],
#        [-0.00013712]]), 'dweight2': array([[0.0011349 , 0.00115206]]), 'dbias2': array([[-0.00116478]])}
# Cost after iteration# 2950: 0.003648
# grads {'dweight1': array([[-0.00038611,  0.00038279],
#        [ 0.00027916, -0.00028175]]), 'dbias1': array([[-0.0001893 ],
#        [-0.00013451]]), 'dweight2': array([[0.0011152 , 0.00113192]]), 'dbias2': array([[-0.00114439]])}
# Cost after iteration# 3000: 0.003584
# grads {'dweight1': array([[-0.00037833,  0.00037506],
#        [ 0.0002739 , -0.00027649]]), 'dbias1': array([[-0.00018546],
#        [-0.000132  ]]), 'dweight2': array([[0.00109617, 0.00111248]]), 'dbias2': array([[-0.00112471]])}
# Cost after iteration# 3050: 0.003522
# grads {'dweight1': array([[-0.00037084,  0.00036761],
#        [ 0.00026883, -0.00027142]]), 'dbias1': array([[-0.00018176],
#        [-0.00012957]]), 'dweight2': array([[0.00107777, 0.00109369]]), 'dbias2': array([[-0.00110569]])}
# Cost after iteration# 3100: 0.003463
# grads {'dweight1': array([[-0.00036362,  0.00036044],
#        [ 0.00026394, -0.00026653]]), 'dbias1': array([[-0.0001782 ],
#        [-0.00012723]]), 'dweight2': array([[0.00105999, 0.00107552]]), 'dbias2': array([[-0.0010873]])}
# Cost after iteration# 3150: 0.003405
# grads {'dweight1': array([[-0.00035667,  0.00035352],
#        [ 0.00025922, -0.0002618 ]]), 'dbias1': array([[-0.00017477],
#        [-0.00012497]]), 'dweight2': array([[0.00104278, 0.00105795]]), 'dbias2': array([[-0.00106952]])}
# Cost after iteration# 3200: 0.003349
# grads {'dweight1': array([[-0.00034995,  0.00034685],
#        [ 0.00025465, -0.00025723]]), 'dbias1': array([[-0.00017146],
#        [-0.00012278]]), 'dweight2': array([[0.00102612, 0.00104095]]), 'dbias2': array([[-0.0010523]])}
# Cost after iteration# 3250: 0.003295
# grads {'dweight1': array([[-0.00034347,  0.00034041],
#        [ 0.00025024, -0.00025281]]), 'dbias1': array([[-0.00016826],
#        [-0.00012067]]), 'dweight2': array([[0.00100999, 0.00102448]]), 'dbias2': array([[-0.00103564]])}
# Cost after iteration# 3300: 0.003243
# grads {'dweight1': array([[-0.00033721,  0.0003342 ],
#        [ 0.00024597, -0.00024854]]), 'dbias1': array([[-0.00016518],
#        [-0.00011862]]), 'dweight2': array([[0.00099436, 0.00100852]]), 'dbias2': array([[-0.00101949]])}
# Cost after iteration# 3350: 0.003192
# grads {'dweight1': array([[-0.00033117,  0.00032819],
#        [ 0.00024184, -0.0002444 ]]), 'dbias1': array([[-0.0001622 ],
#        [-0.00011664]]), 'dweight2': array([[0.0009792 , 0.00099306]]), 'dbias2': array([[-0.00100384]])}
# Cost after iteration# 3400: 0.003143
# grads {'dweight1': array([[-0.00032532,  0.00032238],
#        [ 0.00023784, -0.00024039]]), 'dbias1': array([[-0.00015932],
#        [-0.00011473]]), 'dweight2': array([[0.0009645 , 0.00097806]]), 'dbias2': array([[-0.00098866]])}
# Cost after iteration# 3450: 0.003095
# grads {'dweight1': array([[-0.00031966,  0.00031676],
#        [ 0.00023396, -0.00023651]]), 'dbias1': array([[-0.00015653],
#        [-0.00011287]]), 'dweight2': array([[0.00095024, 0.00096351]]), 'dbias2': array([[-0.00097393]])}
# Cost after iteration# 3500: 0.003049
# grads {'dweight1': array([[-0.00031419,  0.00031132],
#        [ 0.00023021, -0.00023274]]), 'dbias1': array([[-0.00015384],
#        [-0.00011107]]), 'dweight2': array([[0.00093639, 0.00094938]]), 'dbias2': array([[-0.00095964]])}
# Cost after iteration# 3550: 0.003004
# grads {'dweight1': array([[-0.00030889,  0.00030606],
#        [ 0.00022656, -0.00022909]]), 'dbias1': array([[-0.00015123],
#        [-0.00010932]]), 'dweight2': array([[0.00092294, 0.00093566]]), 'dbias2': array([[-0.00094576]])}
# Cost after iteration# 3600: 0.002960
# grads {'dweight1': array([[-0.00030375,  0.00030096],
#        [ 0.00022303, -0.00022554]]), 'dbias1': array([[-0.0001487 ],
#        [-0.00010763]]), 'dweight2': array([[0.00090988, 0.00092233]]), 'dbias2': array([[-0.00093227]])}
# Cost after iteration# 3650: 0.002918
# grads {'dweight1': array([[-0.00029878,  0.00029601],
#        [ 0.0002196 , -0.0002221 ]]), 'dbias1': array([[-0.00014625],
#        [-0.00010599]]), 'dweight2': array([[0.00089717, 0.00090938]]), 'dbias2': array([[-0.00091917]])}
# Cost after iteration# 3700: 0.002877
# grads {'dweight1': array([[-0.00029395,  0.00029122],
#        [ 0.00021627, -0.00021876]]), 'dbias1': array([[-0.00014388],
#        [-0.00010439]]), 'dweight2': array([[0.00088482, 0.00089679]]), 'dbias2': array([[-0.00090643]])}
# Cost after iteration# 3750: 0.002837
# grads {'dweight1': array([[-0.00028927,  0.00028657],
#        [ 0.00021304, -0.00021552]]), 'dbias1': array([[-0.00014157],
#        [-0.00010284]]), 'dweight2': array([[0.00087281, 0.00088454]]), 'dbias2': array([[-0.00089403]])}
# Cost after iteration# 3800: 0.002798
# grads {'dweight1': array([[-0.00028473,  0.00028206],
#        [ 0.0002099 , -0.00021236]]), 'dbias1': array([[-0.00013934],
#        [-0.00010133]]), 'dweight2': array([[0.00086111, 0.00087262]]), 'dbias2': array([[-0.00088197]])}
# Cost after iteration# 3850: 0.002760
# grads {'dweight1': array([[-0.00028032,  0.00027768],
#        [ 0.00020684, -0.0002093 ]]), 'dbias1': array([[-1.37169187e-04],
#        [-9.98653510e-05]]), 'dweight2': array([[0.00084973, 0.00086102]]), 'dbias2': array([[-0.00087024]])}
# Cost after iteration# 3900: 0.002723
# grads {'dweight1': array([[-0.00027603,  0.00027343],
#        [ 0.00020387, -0.00020631]]), 'dbias1': array([[-1.35062328e-04],
#        [-9.84402140e-05]]), 'dweight2': array([[0.00083864, 0.00084972]]), 'dbias2': array([[-0.00085881]])}
# Cost after iteration# 3950: 0.002687
# grads {'dweight1': array([[-0.00027187,  0.00026929],
#        [ 0.00020098, -0.00020341]]), 'dbias1': array([[-1.33015515e-04],
#        [-9.70536708e-05]]), 'dweight2': array([[0.00082784, 0.00083871]]), 'dbias2': array([[-0.00084767]])}
# Cost after iteration# 4000: 0.002652
# grads {'dweight1': array([[-0.00026782,  0.00026528],
#        [ 0.00019817, -0.00020059]]), 'dbias1': array([[-1.31026273e-04],
#        [-9.57041958e-05]]), 'dweight2': array([[0.00081732, 0.00082799]]), 'dbias2': array([[-0.00083682]])}
# Cost after iteration# 4050: 0.002618
# grads {'dweight1': array([[-0.00026389,  0.00026137],
#        [ 0.00019543, -0.00019783]]), 'dbias1': array([[-1.29092264e-04],
#        [-9.43903421e-05]]), 'dweight2': array([[0.00080706, 0.00081753]]), 'dbias2': array([[-0.00082625]])}
# Cost after iteration# 4100: 0.002585
# grads {'dweight1': array([[-0.00026006,  0.00025757],
#        [ 0.00019277, -0.00019516]]), 'dbias1': array([[-1.27211268e-04],
#        [-9.31107369e-05]]), 'dweight2': array([[0.00079705, 0.00080734]]), 'dbias2': array([[-0.00081594]])}
# Cost after iteration# 4150: 0.002552
# grads {'dweight1': array([[-0.00025634,  0.00025387],
#        [ 0.00019017, -0.00019254]]), 'dbias1': array([[-1.25381186e-04],
#        [-9.18640761e-05]]), 'dweight2': array([[0.00078729, 0.0007974 ]]), 'dbias2': array([[-0.00080588]])}
# Cost after iteration# 4200: 0.002521
# grads {'dweight1': array([[-0.00025271,  0.00025028],
#        [ 0.00018764, -0.00019   ]]), 'dbias1': array([[-1.23600023e-04],
#        [-9.06491208e-05]]), 'dweight2': array([[0.00077777, 0.0007877 ]]), 'dbias2': array([[-0.00079607]])}
# Cost after iteration# 4250: 0.002490
# grads {'dweight1': array([[-0.00024919,  0.00024677],
#        [ 0.00018517, -0.00018752]]), 'dbias1': array([[-1.21865889e-04],
#        [-8.94646930e-05]]), 'dweight2': array([[0.00076847, 0.00077823]]), 'dbias2': array([[-0.0007865]])}
# Cost after iteration# 4300: 0.002460
# grads {'dweight1': array([[-0.00024575,  0.00024336],
#        [ 0.00018277, -0.0001851 ]]), 'dbias1': array([[-1.20176987e-04],
#        [-8.83096719e-05]]), 'dweight2': array([[0.0007594 , 0.00076899]]), 'dbias2': array([[-0.00077715]])}
# Cost after iteration# 4350: 0.002431
# grads {'dweight1': array([[-0.0002424 ,  0.00024004],
#        [ 0.00018042, -0.00018274]]), 'dbias1': array([[-1.18531609e-04],
#        [-8.71829905e-05]]), 'dweight2': array([[0.00075053, 0.00075997]]), 'dbias2': array([[-0.00076802]])}
# Cost after iteration# 4400: 0.002402
# grads {'dweight1': array([[-0.00023913,  0.0002368 ],
#        [ 0.00017813, -0.00018044]]), 'dbias1': array([[-1.16928131e-04],
#        [-8.60836324e-05]]), 'dweight2': array([[0.00074188, 0.00075115]]), 'dbias2': array([[-0.00075911]])}
# Cost after iteration# 4450: 0.002374
# grads {'dweight1': array([[-0.00023595,  0.00023364],
#        [ 0.0001759 , -0.00017819]]), 'dbias1': array([[-1.1536501e-04],
#        [-8.5010629e-05]]), 'dweight2': array([[0.00073342, 0.00074254]]), 'dbias2': array([[-0.0007504]])}
# Cost after iteration# 4500: 0.002347
# grads {'dweight1': array([[-0.00023285,  0.00023056],
#        [ 0.00017372, -0.000176  ]]), 'dbias1': array([[-1.13840774e-04],
#        [-8.39630566e-05]]), 'dweight2': array([[0.00072515, 0.00073412]]), 'dbias2': array([[-0.00074188]])}
# Cost after iteration# 4550: 0.002320
# grads {'dweight1': array([[-0.00022982,  0.00022755],
#        [ 0.00017159, -0.00017385]]), 'dbias1': array([[-1.12354022e-04],
#        [-8.29400337e-05]]), 'dweight2': array([[0.00071706, 0.00072589]]), 'dbias2': array([[-0.00073356]])}
# Cost after iteration# 4600: 0.002294
# grads {'dweight1': array([[-0.00022686,  0.00022462],
#        [ 0.00016951, -0.00017176]]), 'dbias1': array([[-1.10903419e-04],
#        [-8.19407190e-05]]), 'dweight2': array([[0.00070916, 0.00071785]]), 'dbias2': array([[-0.00072543]])}
# Cost after iteration# 4650: 0.002268
# grads {'dweight1': array([[-0.00022398,  0.00022176],
#        [ 0.00016747, -0.00016971]]), 'dbias1': array([[-1.09487692e-04],
#        [-8.09643088e-05]]), 'dweight2': array([[0.00070142, 0.00070998]]), 'dbias2': array([[-0.00071747]])}
# Cost after iteration# 4700: 0.002243
# grads {'dweight1': array([[-0.00022116,  0.00021896],
#        [ 0.00016549, -0.00016771]]), 'dbias1': array([[-1.08105626e-04],
#        [-8.00100352e-05]]), 'dweight2': array([[0.00069386, 0.00070228]]), 'dbias2': array([[-0.00070968]])}
# Cost after iteration# 4750: 0.002219
# grads {'dweight1': array([[-0.00021841,  0.00021624],
#        [ 0.00016355, -0.00016576]]), 'dbias1': array([[-1.06756060e-04],
#        [-7.90771639e-05]]), 'dweight2': array([[0.00068645, 0.00069475]]), 'dbias2': array([[-0.00070206]])}
# Cost after iteration# 4800: 0.002195
# grads {'dweight1': array([[-0.00021573,  0.00021357],
#        [ 0.00016165, -0.00016385]]), 'dbias1': array([[-1.05437888e-04],
#        [-7.81649925e-05]]), 'dweight2': array([[0.0006792 , 0.00068737]]), 'dbias2': array([[-0.00069461]])}
# Cost after iteration# 4850: 0.002171
# grads {'dweight1': array([[-0.0002131 ,  0.00021097],
#        [ 0.00015979, -0.00016198]]), 'dbias1': array([[-1.04150050e-04],
#        [-7.72728489e-05]]), 'dweight2': array([[0.00067211, 0.00068015]]), 'dbias2': array([[-0.00068731]])}
# Cost after iteration# 4900: 0.002148
# grads {'dweight1': array([[-0.00021054,  0.00020842],
#        [ 0.00015798, -0.00016015]]), 'dbias1': array([[-1.02891534e-04],
#        [-7.64000894e-05]]), 'dweight2': array([[0.00066516, 0.00067308]]), 'dbias2': array([[-0.00068016]])}
# Cost after iteration# 4950: 0.002126
# grads {'dweight1': array([[-0.00020803,  0.00020594],
#        [ 0.0001562 , -0.00015836]]), 'dbias1': array([[-1.01661372e-04],
#        [-7.55460975e-05]]), 'dweight2': array([[0.00065835, 0.00066616]]), 'dbias2': array([[-0.00067316]])}
# Cost after iteration# 5000: 0.002104
# grads {'dweight1': array([[-0.00020558,  0.0002035 ],
#        [ 0.00015446, -0.00015661]]), 'dbias1': array([[-1.00458638e-04],
#        [-7.47102824e-05]]), 'dweight2': array([[0.00065168, 0.00065938]]), 'dbias2': array([[-0.0006663]])}
# Cost after iteration# 5050: 0.002082
# grads {'dweight1': array([[-0.00020318,  0.00020112],
#        [ 0.00015276, -0.00015489]]), 'dbias1': array([[-9.92824451e-05],
#        [-7.38920777e-05]]), 'dweight2': array([[0.00064515, 0.00065273]]), 'dbias2': array([[-0.00065958]])}
# Cost after iteration# 5100: 0.002061
# grads {'dweight1': array([[-0.00020084,  0.0001988 ],
#        [ 0.0001511 , -0.00015321]]), 'dbias1': array([[-9.81319426e-05],
#        [-7.30909400e-05]]), 'dweight2': array([[0.00063874, 0.00064622]]), 'dbias2': array([[-0.00065299]])}
# Cost after iteration# 5150: 0.002040
# grads {'dweight1': array([[-0.00019854,  0.00019652],
#        [ 0.00014946, -0.00015157]]), 'dbias1': array([[-9.70063168e-05],
#        [-7.23063480e-05]]), 'dweight2': array([[0.00063247, 0.00063984]]), 'dbias2': array([[-0.00064654]])}
# Cost after iteration# 5200: 0.002020
# grads {'dweight1': array([[-0.0001963 ,  0.00019429],
#        [ 0.00014787, -0.00014996]]), 'dbias1': array([[-9.59047871e-05],
#        [-7.15378012e-05]]), 'dweight2': array([[0.00062631, 0.00063358]]), 'dbias2': array([[-0.00064021]])}
# Cost after iteration# 5250: 0.002000
# grads {'dweight1': array([[-0.0001941 ,  0.00019211],
#        [ 0.0001463 , -0.00014838]]), 'dbias1': array([[-9.48266049e-05],
#        [-7.07848189e-05]]), 'dweight2': array([[0.00062027, 0.00062744]]), 'dbias2': array([[-0.000634]])}
# Cost after iteration# 5300: 0.001981
# grads {'dweight1': array([[-0.00019194,  0.00018998],
#        [ 0.00014477, -0.00014683]]), 'dbias1': array([[-9.37710518e-05],
#        [-7.00469395e-05]]), 'dweight2': array([[0.00061435, 0.00062142]]), 'dbias2': array([[-0.00062792]])}
# Cost after iteration# 5350: 0.001962
# grads {'dweight1': array([[-0.00018984,  0.00018789],
#        [ 0.00014326, -0.00014532]]), 'dbias1': array([[-9.27374383e-05],
#        [-6.93237190e-05]]), 'dweight2': array([[0.00060854, 0.00061552]]), 'dbias2': array([[-0.00062195]])}
# Cost after iteration# 5400: 0.001943
# grads {'dweight1': array([[-0.00018777,  0.00018584],
#        [ 0.00014179, -0.00014383]]), 'dbias1': array([[-9.17251023e-05],
#        [-6.86147308e-05]]), 'dweight2': array([[0.00060284, 0.00060972]]), 'dbias2': array([[-0.00061609]])}
# Cost after iteration# 5450: 0.001925
# grads {'dweight1': array([[-0.00018575,  0.00018383],
#        [ 0.00014035, -0.00014237]]), 'dbias1': array([[-9.07334078e-05],
#        [-6.79195645e-05]]), 'dweight2': array([[0.00059725, 0.00060404]]), 'dbias2': array([[-0.00061034]])}
# Cost after iteration# 5500: 0.001906
# grads {'dweight1': array([[-0.00018377,  0.00018187],
#        [ 0.00013893, -0.00014094]]), 'dbias1': array([[-8.97617436e-05],
#        [-6.72378251e-05]]), 'dweight2': array([[0.00059176, 0.00059846]]), 'dbias2': array([[-0.0006047]])}
# Cost after iteration# 5550: 0.001889
# grads {'dweight1': array([[-0.00018182,  0.00017994],
#        [ 0.00013754, -0.00013954]]), 'dbias1': array([[-8.88095219e-05],
#        [-6.65691327e-05]]), 'dweight2': array([[0.00058637, 0.00059298]]), 'dbias2': array([[-0.00059916]])}
# Cost after iteration# 5600: 0.001871
# grads {'dweight1': array([[-0.00017992,  0.00017805],
#        [ 0.00013618, -0.00013817]]), 'dbias1': array([[-8.78761777e-05],
#        [-6.59131211e-05]]), 'dweight2': array([[0.00058107, 0.0005876 ]]), 'dbias2': array([[-0.00059372]])}
# Cost after iteration# 5650: 0.001854
# grads {'dweight1': array([[-0.00017805,  0.0001762 ],
#        [ 0.00013484, -0.00013682]]), 'dbias1': array([[-8.69611673e-05],
#        [-6.52694378e-05]]), 'dweight2': array([[0.00057587, 0.00058232]]), 'dbias2': array([[-0.00058838]])}
# Cost after iteration# 5700: 0.001837
# grads {'dweight1': array([[-0.00017622,  0.00017439],
#        [ 0.00013353, -0.00013549]]), 'dbias1': array([[-8.60639673e-05],
#        [-6.46377433e-05]]), 'dweight2': array([[0.00057077, 0.00057713]]), 'dbias2': array([[-0.00058313]])}
# Cost after iteration# 5750: 0.001821
# grads {'dweight1': array([[-0.00017442,  0.0001726 ],
#        [ 0.00013224, -0.00013419]]), 'dbias1': array([[-8.51840741e-05],
#        [-6.40177100e-05]]), 'dweight2': array([[0.00056575, 0.00057203]]), 'dbias2': array([[-0.00057798]])}
# Cost after iteration# 5800: 0.001805
# grads {'dweight1': array([[-0.00017266,  0.00017086],
#        [ 0.00013097, -0.00013292]]), 'dbias1': array([[-8.43210023e-05],
#        [-6.34090224e-05]]), 'dweight2': array([[0.00056082, 0.00056702]]), 'dbias2': array([[-0.00057292]])}
# Cost after iteration# 5850: 0.001789
# grads {'dweight1': array([[-0.00017094,  0.00016914],
#        [ 0.00012973, -0.00013166]]), 'dbias1': array([[-8.34742847e-05],
#        [-6.28113760e-05]]), 'dweight2': array([[0.00055598, 0.0005621 ]]), 'dbias2': array([[-0.00056794]])}
# Cost after iteration# 5900: 0.001773
# grads {'dweight1': array([[-0.00016924,  0.00016746],
#        [ 0.00012851, -0.00013043]]), 'dbias1': array([[-8.26434708e-05],
#        [-6.22244771e-05]]), 'dweight2': array([[0.00055122, 0.00055727]]), 'dbias2': array([[-0.00056305]])}
# Cost after iteration# 5950: 0.001758
# grads {'dweight1': array([[-0.00016758,  0.00016581],
#        [ 0.00012732, -0.00012922]]), 'dbias1': array([[-8.18281261e-05],
#        [-6.16480422e-05]]), 'dweight2': array([[0.00054654, 0.00055252]]), 'dbias2': array([[-0.00055825]])}
# Cost after iteration# 6000: 0.001743
# grads {'dweight1': array([[-0.00016594,  0.00016419],
#        [ 0.00012614, -0.00012804]]), 'dbias1': array([[-8.10278321e-05],
#        [-6.10817977e-05]]), 'dweight2': array([[0.00054194, 0.00054784]]), 'dbias2': array([[-0.00055352]])}
# Cost after iteration# 6050: 0.001728
# grads {'dweight1': array([[-0.00016434,  0.0001626 ],
#        [ 0.00012498, -0.00012687]]), 'dbias1': array([[-8.02421847e-05],
#        [-6.05254792e-05]]), 'dweight2': array([[0.00053742, 0.00054325]]), 'dbias2': array([[-0.00054888]])}
# Cost after iteration# 6100: 0.001713
# grads {'dweight1': array([[-0.00016276,  0.00016104],
#        [ 0.00012385, -0.00012572]]), 'dbias1': array([[-7.94707940e-05],
#        [-5.99788315e-05]]), 'dweight2': array([[0.00053297, 0.00053873]]), 'dbias2': array([[-0.00054431]])}
# Cost after iteration# 6150: 0.001699
# grads {'dweight1': array([[-0.00016122,  0.00015951],
#        [ 0.00012273, -0.0001246 ]]), 'dbias1': array([[-7.87132839e-05],
#        [-5.94416081e-05]]), 'dweight2': array([[0.00052859, 0.00053429]]), 'dbias2': array([[-0.00053982]])}
# Cost after iteration# 6200: 0.001685
# grads {'dweight1': array([[-0.0001597 ,  0.000158  ],
#        [ 0.00012164, -0.00012349]]), 'dbias1': array([[-7.79692909e-05],
#        [-5.89135704e-05]]), 'dweight2': array([[0.00052429, 0.00052992]]), 'dbias2': array([[-0.0005354]])}
# Cost after iteration# 6250: 0.001671
# grads {'dweight1': array([[-0.0001582 ,  0.00015652],
#        [ 0.00012056, -0.0001224 ]]), 'dbias1': array([[-7.72384643e-05],
#        [-5.83944880e-05]]), 'dweight2': array([[0.00052005, 0.00052562]]), 'dbias2': array([[-0.00053106]])}
# Cost after iteration# 6300: 0.001657
# grads {'dweight1': array([[-0.00015674,  0.00015507],
#        [ 0.0001195 , -0.00012133]]), 'dbias1': array([[-7.65204651e-05],
#        [-5.78841381e-05]]), 'dweight2': array([[0.00051589, 0.00052139]]), 'dbias2': array([[-0.00052678]])}
# Cost after iteration# 6350: 0.001644
# grads {'dweight1': array([[-0.0001553 ,  0.00015364],
#        [ 0.00011846, -0.00012028]]), 'dbias1': array([[-7.58149656e-05],
#        [-5.73823049e-05]]), 'dweight2': array([[0.00051179, 0.00051723]]), 'dbias2': array([[-0.00052257]])}
# Cost after iteration# 6400: 0.001631
# grads {'dweight1': array([[-0.00015388,  0.00015224],
#        [ 0.00011743, -0.00011924]]), 'dbias1': array([[-7.51216493e-05],
#        [-5.68887800e-05]]), 'dweight2': array([[0.00050775, 0.00051313]]), 'dbias2': array([[-0.00051843]])}
# Cost after iteration# 6450: 0.001618
# grads {'dweight1': array([[-0.00015249,  0.00015086],
#        [ 0.00011643, -0.00011822]]), 'dbias1': array([[-7.44402099e-05],
#        [-5.64033615e-05]]), 'dweight2': array([[0.00050378, 0.0005091 ]]), 'dbias2': array([[-0.00051435]])}
# Cost after iteration# 6500: 0.001605
# grads {'dweight1': array([[-0.00015112,  0.0001495 ],
#        [ 0.00011544, -0.00011722]]), 'dbias1': array([[-7.37703514e-05],
#        [-5.59258538e-05]]), 'dweight2': array([[0.00049987, 0.00050513]]), 'dbias2': array([[-0.00051034]])}
# Cost after iteration# 6550: 0.001592
# grads {'dweight1': array([[-0.00014978,  0.00014817],
#        [ 0.00011446, -0.00011624]]), 'dbias1': array([[-7.31117873e-05],
#        [-5.54560678e-05]]), 'dweight2': array([[0.00049602, 0.00050122]]), 'dbias2': array([[-0.00050639]])}
# Cost after iteration# 6600: 0.001580
# grads {'dweight1': array([[-0.00014845,  0.00014686],
#        [ 0.0001135 , -0.00011527]]), 'dbias1': array([[-7.24642404e-05],
#        [-5.49938200e-05]]), 'dweight2': array([[0.00049223, 0.00049737]]), 'dbias2': array([[-0.0005025]])}
# Cost after iteration# 6650: 0.001568
# grads {'dweight1': array([[-0.00014715,  0.00014557],
#        [ 0.00011256, -0.00011431]]), 'dbias1': array([[-7.18274424e-05],
#        [-5.45389330e-05]]), 'dweight2': array([[0.0004885 , 0.00049358]]), 'dbias2': array([[-0.00049867]])}
# Cost after iteration# 6700: 0.001556
# grads {'dweight1': array([[-0.00014587,  0.0001443 ],
#        [ 0.00011163, -0.00011337]]), 'dbias1': array([[-7.12011335e-05],
#        [-5.40912346e-05]]), 'dweight2': array([[0.00048482, 0.00048985]]), 'dbias2': array([[-0.0004949]])}
# Cost after iteration# 6750: 0.001544
# grads {'dweight1': array([[-0.00014462,  0.00014305],
#        [ 0.00011071, -0.00011245]]), 'dbias1': array([[-7.05850622e-05],
#        [-5.36505579e-05]]), 'dweight2': array([[0.0004812 , 0.00048618]]), 'dbias2': array([[-0.00049118]])}
# Cost after iteration# 6800: 0.001532
# grads {'dweight1': array([[-0.00014338,  0.00014183],
#        [ 0.00010981, -0.00011154]]), 'dbias1': array([[-6.99789847e-05],
#        [-5.32167414e-05]]), 'dweight2': array([[0.00047763, 0.00048256]]), 'dbias2': array([[-0.00048752]])}
# Cost after iteration# 6850: 0.001521
# grads {'dweight1': array([[-0.00014216,  0.00014062],
#        [ 0.00010893, -0.00011064]]), 'dbias1': array([[-6.93826651e-05],
#        [-5.27896281e-05]]), 'dweight2': array([[0.00047412, 0.00047899]]), 'dbias2': array([[-0.00048392]])}
# Cost after iteration# 6900: 0.001509
# grads {'dweight1': array([[-0.00014096,  0.00013943],
#        [ 0.00010806, -0.00010976]]), 'dbias1': array([[-6.87958746e-05],
#        [-5.23690659e-05]]), 'dweight2': array([[0.00047065, 0.00047548]]), 'dbias2': array([[-0.00048037]])}
# Cost after iteration# 6950: 0.001498
# grads {'dweight1': array([[-0.00013978,  0.00013826],
#        [ 0.0001072 , -0.00010889]]), 'dbias1': array([[-6.82183912e-05],
#        [-5.19549072e-05]]), 'dweight2': array([[0.00046724, 0.00047201]]), 'dbias2': array([[-0.00047686]])}
# Cost after iteration# 7000: 0.001487
# grads {'dweight1': array([[-0.00013862,  0.00013711],
#        [ 0.00010635, -0.00010804]]), 'dbias1': array([[-6.76500001e-05],
#        [-5.15470089e-05]]), 'dweight2': array([[0.00046387, 0.0004686 ]]), 'dbias2': array([[-0.00047341]])}
# Cost after iteration# 7050: 0.001477
# grads {'dweight1': array([[-0.00013747,  0.00013598],
#        [ 0.00010552, -0.00010719]]), 'dbias1': array([[-6.70904926e-05],
#        [-5.11452319e-05]]), 'dweight2': array([[0.00046056, 0.00046523]]), 'dbias2': array([[-0.00047001]])}
# Cost after iteration# 7100: 0.001466
# grads {'dweight1': array([[-0.00013635,  0.00013486],
#        [ 0.0001047 , -0.00010636]]), 'dbias1': array([[-6.65396666e-05],
#        [-5.07494412e-05]]), 'dweight2': array([[0.00045729, 0.00046192]]), 'dbias2': array([[-0.00046666]])}
# Cost after iteration# 7150: 0.001455
# grads {'dweight1': array([[-0.00013524,  0.00013376],
#        [ 0.00010389, -0.00010555]]), 'dbias1': array([[-6.59973257e-05],
#        [-5.03595059e-05]]), 'dweight2': array([[0.00045407, 0.00045865]]), 'dbias2': array([[-0.00046336]])}
# Cost after iteration# 7200: 0.001445
# grads {'dweight1': array([[-0.00013415,  0.00013268],
#        [ 0.00010309, -0.00010474]]), 'dbias1': array([[-6.54632795e-05],
#        [-4.99752987e-05]]), 'dweight2': array([[0.00045089, 0.00045543]]), 'dbias2': array([[-0.0004601]])}
# Cost after iteration# 7250: 0.001435
# grads {'dweight1': array([[-0.00013307,  0.00013162],
#        [ 0.00010231, -0.00010395]]), 'dbias1': array([[-6.49373431e-05],
#        [-4.95966959e-05]]), 'dweight2': array([[0.00044776, 0.00045225]]), 'dbias2': array([[-0.00045688]])}
# Cost after iteration# 7300: 0.001425
# grads {'dweight1': array([[-0.00013202,  0.00013057],
#        [ 0.00010153, -0.00010316]]), 'dbias1': array([[-6.44193371e-05],
#        [-4.92235774e-05]]), 'dweight2': array([[0.00044467, 0.00044911]]), 'dbias2': array([[-0.00045372]])}
# Cost after iteration# 7350: 0.001415
# grads {'dweight1': array([[-0.00013097,  0.00012954],
#        [ 0.00010077, -0.00010239]]), 'dbias1': array([[-6.39090873e-05],
#        [-4.88558264e-05]]), 'dweight2': array([[0.00044162, 0.00044602]]), 'dbias2': array([[-0.00045059]])}
# Cost after iteration# 7400: 0.001405
# grads {'dweight1': array([[-0.00012994,  0.00012852],
#        [ 0.00010002, -0.00010163]]), 'dbias1': array([[-6.34064243e-05],
#        [-4.84933296e-05]]), 'dweight2': array([[0.00043861, 0.00044297]]), 'dbias2': array([[-0.00044751]])}
# Cost after iteration# 7450: 0.001395
# grads {'dweight1': array([[-1.28932523e-04,  1.27514916e-04],
#        [ 9.92766435e-05, -1.00881775e-04]]), 'dbias1': array([[-6.29111837e-05],
#        [-4.81359766e-05]]), 'dweight2': array([[0.00043565, 0.00043997]]), 'dbias2': array([[-0.00044447]])}
# Cost after iteration# 7500: 0.001386
# grads {'dweight1': array([[-1.27934970e-04,  1.26526601e-04],
#        [ 9.85462086e-05, -1.00142674e-04]]), 'dbias1': array([[-6.24232058e-05],
#        [-4.77836600e-05]]), 'dweight2': array([[0.00043272, 0.000437  ]]), 'dbias2': array([[-0.00044147]])}
# Cost after iteration# 7550: 0.001376
# grads {'dweight1': array([[-1.26951910e-04,  1.25552663e-04],
#        [ 9.78260346e-05, -9.94139145e-05]]), 'dbias1': array([[-6.19423353e-05],
#        [-4.74362757e-05]]), 'dweight2': array([[0.00042984, 0.00043407]]), 'dbias2': array([[-0.00043851]])}
# Cost after iteration# 7600: 0.001367
# grads {'dweight1': array([[-1.25983036e-04,  1.24592798e-04],
#        [ 9.71159100e-05, -9.86952845e-05]]), 'dbias1': array([[-6.14684213e-05],
#        [-4.70937221e-05]]), 'dweight2': array([[0.00042699, 0.00043118]]), 'dbias2': array([[-0.00043559]])}
# Cost after iteration# 7650: 0.001358
# grads {'dweight1': array([[-1.25028050e-04,  1.23646708e-04],
#        [ 9.64156286e-05, -9.79865768e-05]]), 'dbias1': array([[-6.10013171e-05],
#        [-4.67559004e-05]]), 'dweight2': array([[0.00042418, 0.00042833]]), 'dbias2': array([[-0.00043271]])}
# Cost after iteration# 7700: 0.001349
# grads {'dweight1': array([[-1.24086660e-04,  1.22714106e-04],
#        [ 9.57249902e-05, -9.72875902e-05]]), 'dbias1': array([[-6.05408799e-05],
#        [-4.64227146e-05]]), 'dweight2': array([[0.0004214 , 0.00042552]]), 'dbias2': array([[-0.00042987]])}
# Cost after iteration# 7750: 0.001340
# grads {'dweight1': array([[-1.23158585e-04,  1.21794711e-04],
#        [ 9.50437996e-05, -9.65981288e-05]]), 'dbias1': array([[-6.00869711e-05],
#        [-4.60940712e-05]]), 'dweight2': array([[0.00041867, 0.00042275]]), 'dbias2': array([[-0.00042707]])}
# Cost after iteration# 7800: 0.001331
# grads {'dweight1': array([[-1.22243551e-04,  1.20888251e-04],
#        [ 9.43718671e-05, -9.59180018e-05]]), 'dbias1': array([[-5.96394557e-05],
#        [-4.57698790e-05]]), 'dweight2': array([[0.00041597, 0.00042001]]), 'dbias2': array([[-0.0004243]])}
# Cost after iteration# 7850: 0.001322
# grads {'dweight1': array([[-1.21341289e-04,  1.19994460e-04],
#        [ 9.37090078e-05, -9.52470236e-05]]), 'dbias1': array([[-5.91982022e-05],
#        [-4.54500496e-05]]), 'dweight2': array([[0.0004133, 0.0004173]]), 'dbias2': array([[-0.00042156]])}
# Cost after iteration# 7900: 0.001314
# grads {'dweight1': array([[-1.20451541e-04,  1.19113080e-04],
#        [ 9.30550416e-05, -9.45850134e-05]]), 'dbias1': array([[-5.87630830e-05],
#        [-4.51344965e-05]]), 'dweight2': array([[0.00041066, 0.00041463]]), 'dbias2': array([[-0.00041886]])}
# Cost after iteration# 7950: 0.001305
# grads {'dweight1': array([[-1.19574052e-04,  1.18243860e-04],
#        [ 9.24097934e-05, -9.39317950e-05]]), 'dbias1': array([[-5.83339737e-05],
#        [-4.48231357e-05]]), 'dweight2': array([[0.00040806, 0.000412  ]]), 'dbias2': array([[-0.0004162]])}
# Cost after iteration# 8000: 0.001297
# grads {'dweight1': array([[-1.18708577e-04,  1.17386556e-04],
#        [ 9.17730923e-05, -9.32871969e-05]]), 'dbias1': array([[-5.79107531e-05],
#        [-4.45158853e-05]]), 'dweight2': array([[0.0004055, 0.0004094]]), 'dbias2': array([[-0.00041357]])}
# Cost after iteration# 8050: 0.001289
# grads {'dweight1': array([[-1.17854875e-04,  1.16540928e-04],
#        [ 9.11447720e-05, -9.26510517e-05]]), 'dbias1': array([[-5.74933035e-05],
#        [-4.42126655e-05]]), 'dweight2': array([[0.00040296, 0.00040683]]), 'dbias2': array([[-0.00041097]])}
# Cost after iteration# 8100: 0.001281
# grads {'dweight1': array([[-1.17012713e-04,  1.15706745e-04],
#        [ 9.05246705e-05, -9.20231968e-05]]), 'dbias1': array([[-5.70815099e-05],
#        [-4.39133985e-05]]), 'dweight2': array([[0.00040046, 0.00040429]]), 'dbias2': array([[-0.00040841]])}
# Cost after iteration# 8150: 0.001273
# grads {'dweight1': array([[-1.16181864e-04,  1.14883781e-04],
#        [ 8.99126297e-05, -9.14034732e-05]]), 'dbias1': array([[-5.66752606e-05],
#        [-4.36180086e-05]]), 'dweight2': array([[0.00039799, 0.00040178]]), 'dbias2': array([[-0.00040588]])}
# Cost after iteration# 8200: 0.001265
# grads {'dweight1': array([[-1.15362105e-04,  1.14071816e-04],
#        [ 8.93084956e-05, -9.07917262e-05]]), 'dbias1': array([[-5.62744467e-05],
#        [-4.33264220e-05]]), 'dweight2': array([[0.00039555, 0.00039931]]), 'dbias2': array([[-0.00040337]])}
# Cost after iteration# 8250: 0.001257
# grads {'dweight1': array([[-1.14553220e-04,  1.13270636e-04],
#        [ 8.87121182e-05, -9.01878049e-05]]), 'dbias1': array([[-5.58789622e-05],
#        [-4.30385665e-05]]), 'dweight2': array([[0.00039313, 0.00039686]]), 'dbias2': array([[-0.0004009]])}
# Cost after iteration# 8300: 0.001249
# grads {'dweight1': array([[-1.13755000e-04,  1.12480031e-04],
#        [ 8.81233511e-05, -8.95915621e-05]]), 'dbias1': array([[-5.54887035e-05],
#        [-4.27543719e-05]]), 'dweight2': array([[0.00039075, 0.00039445]]), 'dbias2': array([[-0.00039846]])}
# Cost after iteration# 8350: 0.001241
# grads {'dweight1': array([[-1.12967239e-04,  1.11699799e-04],
#        [ 8.75420516e-05, -8.90028543e-05]]), 'dbias1': array([[-5.51035699e-05],
#        [-4.24737699e-05]]), 'dweight2': array([[0.0003884 , 0.00039206]]), 'dbias2': array([[-0.00039605]])}
# Cost after iteration# 8400: 0.001234
# grads {'dweight1': array([[-1.12189736e-04,  1.10929739e-04],
#        [ 8.69680805e-05, -8.84215416e-05]]), 'dbias1': array([[-5.47234632e-05],
#        [-4.21966935e-05]]), 'dweight2': array([[0.00038607, 0.00038971]]), 'dbias2': array([[-0.00039367]])}
# Cost after iteration# 8450: 0.001226
# grads {'dweight1': array([[-1.11422298e-04,  1.10169659e-04],
#        [ 8.64013019e-05, -8.78474873e-05]]), 'dbias1': array([[-5.43482877e-05],
#        [-4.19230776e-05]]), 'dweight2': array([[0.00038377, 0.00038738]]), 'dbias2': array([[-0.00039131]])}
# Cost after iteration# 8500: 0.001219
# grads {'dweight1': array([[-1.10664733e-04,  1.09419371e-04],
#        [ 8.58415834e-05, -8.72805583e-05]]), 'dbias1': array([[-5.39779500e-05],
#        [-4.16528587e-05]]), 'dweight2': array([[0.0003815 , 0.00038508]]), 'dbias2': array([[-0.00038899]])}
# Cost after iteration# 8550: 0.001212
# grads {'dweight1': array([[-1.09916857e-04,  1.08678689e-04],
#        [ 8.52887957e-05, -8.67206244e-05]]), 'dbias1': array([[-5.36123590e-05],
#        [-4.13859747e-05]]), 'dweight2': array([[0.00037926, 0.0003828 ]]), 'dbias2': array([[-0.00038669]])}
# Cost after iteration# 8600: 0.001204
# grads {'dweight1': array([[-1.09178488e-04,  1.07947435e-04],
#        [ 8.47428126e-05, -8.61675589e-05]]), 'dbias1': array([[-5.32514259e-05],
#        [-4.11223651e-05]]), 'dweight2': array([[0.00037704, 0.00038055]]), 'dbias2': array([[-0.00038442]])}
# Cost after iteration# 8650: 0.001197
# grads {'dweight1': array([[-1.08449451e-04,  1.07225433e-04],
#        [ 8.42035111e-05, -8.56212378e-05]]), 'dbias1': array([[-5.28950642e-05],
#        [-4.08619707e-05]]), 'dweight2': array([[0.00037485, 0.00037833]]), 'dbias2': array([[-0.00038217]])}
# Cost after iteration# 8700: 0.001190
# grads {'dweight1': array([[-1.07729572e-04,  1.06512513e-04],
#        [ 8.36707709e-05, -8.50815401e-05]]), 'dbias1': array([[-5.25431892e-05],
#        [-4.06047339e-05]]), 'dweight2': array([[0.00037268, 0.00037614]]), 'dbias2': array([[-0.00037996]])}
# Cost after iteration# 8750: 0.001183
# grads {'dweight1': array([[-1.07018685e-04,  1.05808508e-04],
#        [ 8.31444746e-05, -8.45483479e-05]]), 'dbias1': array([[-5.21957185e-05],
#        [-4.03505982e-05]]), 'dweight2': array([[0.00037054, 0.00037397]]), 'dbias2': array([[-0.00037776]])}
# Cost after iteration# 8800: 0.001177
# grads {'dweight1': array([[-1.06316624e-04,  1.05113255e-04],
#        [ 8.26245077e-05, -8.40215458e-05]]), 'dbias1': array([[-5.18525717e-05],
#        [-4.00995088e-05]]), 'dweight2': array([[0.00036842, 0.00037182]]), 'dbias2': array([[-0.00037559]])}
# Cost after iteration# 8850: 0.001170
# grads {'dweight1': array([[-1.05623231e-04,  1.04426595e-04],
#        [ 8.21107582e-05, -8.35010212e-05]]), 'dbias1': array([[-5.15136702e-05],
#        [-3.98514119e-05]]), 'dweight2': array([[0.00036633, 0.0003697 ]]), 'dbias2': array([[-0.00037345]])}
# Cost after iteration# 8900: 0.001163
# grads {'dweight1': array([[-1.04938348e-04,  1.03748373e-04],
#        [ 8.16031169e-05, -8.29866640e-05]]), 'dbias1': array([[-5.11789373e-05],
#        [-3.96062550e-05]]), 'dweight2': array([[0.00036426, 0.00036761]]), 'dbias2': array([[-0.00037133]])}
# Cost after iteration# 8950: 0.001156
# grads {'dweight1': array([[-1.04261824e-04,  1.03078438e-04],
#        [ 8.11014769e-05, -8.24783668e-05]]), 'dbias1': array([[-5.08482980e-05],
#        [-3.93639868e-05]]), 'dweight2': array([[0.00036222, 0.00036553]]), 'dbias2': array([[-0.00036924]])}
# Cost after iteration# 9000: 0.001150
# grads {'dweight1': array([[-1.03593509e-04,  1.02416642e-04],
#        [ 8.06057339e-05, -8.19760246e-05]]), 'dbias1': array([[-5.05216794e-05],
#        [-3.91245572e-05]]), 'dweight2': array([[0.00036019, 0.00036348]]), 'dbias2': array([[-0.00036717]])}
# Cost after iteration# 9050: 0.001143
# grads {'dweight1': array([[-1.02933258e-04,  1.01762841e-04],
#        [ 8.01157859e-05, -8.14795348e-05]]), 'dbias1': array([[-5.01990101e-05],
#        [-3.88879174e-05]]), 'dweight2': array([[0.00035819, 0.00036146]]), 'dbias2': array([[-0.00036512]])}
# Cost after iteration# 9100: 0.001137
# grads {'dweight1': array([[-1.02280928e-04,  1.01116893e-04],
#        [ 7.96315334e-05, -8.09887971e-05]]), 'dbias1': array([[-4.98802202e-05],
#        [-3.86540194e-05]]), 'dweight2': array([[0.00035621, 0.00035945]]), 'dbias2': array([[-0.00036309]])}
# Cost after iteration# 9150: 0.001131
# grads {'dweight1': array([[-1.01636382e-04,  1.00478661e-04],
#        [ 7.91528790e-05, -8.05037135e-05]]), 'dbias1': array([[-4.95652416e-05],
#        [-3.84228165e-05]]), 'dweight2': array([[0.00035426, 0.00035747]]), 'dbias2': array([[-0.00036109]])}
# Cost after iteration# 9200: 0.001124
# grads {'dweight1': array([[-1.00999482e-04,  9.98480106e-05],
#        [ 7.86797275e-05, -8.00241881e-05]]), 'dbias1': array([[-4.92540079e-05],
#        [-3.81942630e-05]]), 'dweight2': array([[0.00035232, 0.00035551]]), 'dbias2': array([[-0.00035911]])}
# Cost after iteration# 9250: 0.001118
# grads {'dweight1': array([[-1.00370098e-04,  9.92248099e-05],
#        [ 7.82119859e-05, -7.95501273e-05]]), 'dbias1': array([[-4.89464540e-05],
#        [-3.79683142e-05]]), 'dweight2': array([[0.00035041, 0.00035357]]), 'dbias2': array([[-0.00035715]])}
# Cost after iteration# 9300: 0.001112
# grads {'dweight1': array([[-9.97480990e-05,  9.86089304e-05],
#        [ 7.77495631e-05, -7.90814395e-05]]), 'dbias1': array([[-4.86425163e-05],
#        [-3.77449264e-05]]), 'dweight2': array([[0.00034852, 0.00035166]]), 'dbias2': array([[-0.00035521]])}
# Cost after iteration# 9350: 0.001106
# grads {'dweight1': array([[-9.91333586e-05,  9.80002466e-05],
#        [ 7.72923703e-05, -7.86180350e-05]]), 'dbias1': array([[-4.83421328e-05],
#        [-3.75240570e-05]]), 'dweight2': array([[0.00034664, 0.00034976]]), 'dbias2': array([[-0.00035329]])}
# Cost after iteration# 9400: 0.001100
# grads {'dweight1': array([[-9.85257531e-05,  9.73986357e-05],
#        [ 7.68403204e-05, -7.81598263e-05]]), 'dbias1': array([[-4.80452426e-05],
#        [-3.73056640e-05]]), 'dweight2': array([[0.00034479, 0.00034788]]), 'dbias2': array([[-0.0003514]])}
# Cost after iteration# 9450: 0.001094
# grads {'dweight1': array([[-9.79251616e-05,  9.68039776e-05],
#        [ 7.63933283e-05, -7.77067276e-05]]), 'dbias1': array([[-4.77517865e-05],
#        [-3.70897067e-05]]), 'dweight2': array([[0.00034296, 0.00034603]]), 'dbias2': array([[-0.00034952]])}
# Cost after iteration# 9500: 0.001088
# grads {'dweight1': array([[-9.73314658e-05,  9.62161549e-05],
#        [ 7.59513107e-05, -7.72586551e-05]]), 'dbias1': array([[-4.74617065e-05],
#        [-3.68761450e-05]]), 'dweight2': array([[0.00034114, 0.00034419]]), 'dbias2': array([[-0.00034767]])}
# Cost after iteration# 9550: 0.001082
# grads {'dweight1': array([[-9.67445500e-05,  9.56350530e-05],
#        [ 7.55141863e-05, -7.68155268e-05]]), 'dbias1': array([[-4.71749457e-05],
#        [-3.66649398e-05]]), 'dweight2': array([[0.00033935, 0.00034237]]), 'dbias2': array([[-0.00034583]])}
# Cost after iteration# 9600: 0.001076
# grads {'dweight1': array([[-9.61643011e-05,  9.50605595e-05],
#        [ 7.50818754e-05, -7.63772624e-05]]), 'dbias1': array([[-4.68914487e-05],
#        [-3.64560528e-05]]), 'dweight2': array([[0.00033757, 0.00034057]]), 'dbias2': array([[-0.00034401]])}
# Cost after iteration# 9650: 0.001071
# grads {'dweight1': array([[-9.55906084e-05,  9.44925646e-05],
#        [ 7.46542999e-05, -7.59437833e-05]]), 'dbias1': array([[-4.66111613e-05],
#        [-3.62494466e-05]]), 'dweight2': array([[0.00033581, 0.00033879]]), 'dbias2': array([[-0.00034221]])}
# Cost after iteration# 9700: 0.001065
# grads {'dweight1': array([[-9.50233637e-05,  9.39309610e-05],
#        [ 7.42313836e-05, -7.55150127e-05]]), 'dbias1': array([[-4.63340303e-05],
#        [-3.60450846e-05]]), 'dweight2': array([[0.00033408, 0.00033703]]), 'dbias2': array([[-0.00034043]])}
# Cost after iteration# 9750: 0.001060
# grads {'dweight1': array([[-9.44624611e-05,  9.33756436e-05],
#        [ 7.38130518e-05, -7.50908753e-05]]), 'dbias1': array([[-4.60600038e-05],
#        [-3.58429307e-05]]), 'dweight2': array([[0.00033235, 0.00033529]]), 'dbias2': array([[-0.00033867]])}
# Cost after iteration# 9800: 0.001054
# grads {'dweight1': array([[-9.39077969e-05,  9.28265096e-05],
#        [ 7.33992313e-05, -7.46712974e-05]]), 'dbias1': array([[-4.57890309e-05],
#        [-3.56429500e-05]]), 'dweight2': array([[0.00033065, 0.00033357]]), 'dbias2': array([[-0.00033693]])}
# Cost after iteration# 9850: 0.001049
# grads {'dweight1': array([[-9.33592698e-05,  9.22834584e-05],
#        [ 7.29898505e-05, -7.42562070e-05]]), 'dbias1': array([[-4.55210620e-05],
#        [-3.54451079e-05]]), 'dweight2': array([[0.00032897, 0.00033186]]), 'dbias2': array([[-0.0003352]])}
# Cost after iteration# 9900: 0.001043
# grads {'dweight1': array([[-9.28167806e-05,  9.17463915e-05],
#        [ 7.25848395e-05, -7.38455333e-05]]), 'dbias1': array([[-4.52560483e-05],
#        [-3.52493709e-05]]), 'dweight2': array([[0.0003273 , 0.00033017]]), 'dbias2': array([[-0.0003335]])}
# Cost after iteration# 9950: 0.001038
# grads {'dweight1': array([[-9.22802320e-05,  9.12152126e-05],
#        [ 7.21841295e-05, -7.34392072e-05]]), 'dbias1': array([[-4.49939423e-05],
#        [-3.50557059e-05]]), 'dweight2': array([[0.00032564, 0.0003285 ]]), 'dbias2': array([[-0.00033181]])}
# Cost after iteration# 10000: 0.001033
# grads {'dweight1': array([[-9.17495291e-05,  9.06898274e-05],
#        [ 7.17876533e-05, -7.30371609e-05]]), 'dbias1': array([[-4.47346973e-05],
#        [-3.48640806e-05]]), 'dweight2': array([[0.00032401, 0.00032684]]), 'dbias2': array([[-0.00033013]])}
# Neural Network prediction for example (1,1) is 0
# Neural Network prediction for example (0,1) is 1
# Neural Network prediction for example (0,0) is 0
# Neural Network prediction for example (1,0) is 1
